# %% [markdown]
# # Forecasting number of passengers traveling per month using FbProphet

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import prophet
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data reading and Visualization

# %%
df=pd.read_csv('airline_passengers.csv')

# %%
df.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                    112.0
# 1  1949-02                    118.0
# 2  1949-03                    132.0
# 3  1949-04                    129.0
# 4  1949-05                    121.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 140                    508.0
# 141                    461.0
# 142                    390.0
# 143                    432.0
# 144                      NaN

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.columns = ['ds','y']
df.head()
# Out:
#         ds      y
# 0  1949-01  112.0
# 1  1949-02  118.0
# 2  1949-03  132.0
# 3  1949-04  129.0
# 4  1949-05  121.0

# %%
df.drop(144,axis=0,inplace=True)

# %%
df.tail()
# Out:
#           ds      y
# 139  1960-08  606.0
# 140  1960-09  508.0
# 141  1960-10  461.0
# 142  1960-11  390.0
# 143  1960-12  432.0

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.head()
# Out:
#           ds      y
# 0 1949-01-01  112.0
# 1 1949-02-01  118.0
# 2 1949-03-01  132.0
# 3 1949-04-01  129.0
# 4 1949-05-01  121.0

# %%
df.tail()
# Out:
#             ds      y
# 139 1960-08-01  606.0
# 140 1960-09-01  508.0
# 141 1960-10-01  461.0
# 142 1960-11-01  390.0
# 143 1960-12-01  432.0

# %%
from prophet import Prophet

# %%
dir(Prophet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load_stan_backend',
#  'add_country_holidays',
#  'add_group_component',
#  'add_regressor',
#  'add_seasonality',
#  'construct_holiday_dataframe',
#  'fit',
#  'flat_growth_init',
#  'flat_trend',
#  'fourier_series',
#  'initialize_scales',
#  'linear_growth_init',
#  'logistic_growth_init',
#  'make_all_seasonality_features',
#  'make_future_dataframe',
#  'make_holiday_features',
#  'make_seasonality_features',
#  'parse_seasonality_args',
#  'percentile',
#  'piecewise_linear',
#  'piecewise_logistic',
#  'plot',
#  'plot_components',
#  'predict',
#  'predict_seasonal_components',
#  'predict_trend',
#  'predict_uncertainty',
#  'predictive_samples',
#  'regressor_column_matrix',
#  'sample_model',
#  'sample_posterior_predictive',
#  'sample_predictive_trend',
#  'set_auto_seasonalities',
#  'set_changepoints',
#  'setup_dataframe',
#  'validate_column_name',
#  'validate_inputs']

# %% [markdown]
# ## Initialize the Model

# %%
model=Prophet()

# %%
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#           ds      y
# 0 1949-01-01  112.0
# 1 1949-02-01  118.0
# 2 1949-03-01  132.0
# 3 1949-04-01  129.0
# 4 1949-05-01  121.0

# %%
model.fit(df)
# Out:
# 13:05:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:05:48 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
df.tail()
# Out:
#             ds      y
# 139 1960-08-01  606.0
# 140 1960-09-01  508.0
# 141 1960-10-01  461.0
# 142 1960-11-01  390.0
# 143 1960-12-01  432.0

# %% [markdown]
# ## Prediction
# ### Create future dates of 365 days

# %%
future_dates=model.make_future_dataframe(periods=365)

# %%
future_dates.tail()
# Out:
#             ds
# 504 1961-11-27
# 505 1961-11-28
# 506 1961-11-29
# 507 1961-11-30
# 508 1961-12-01

# %%
prediction=model.predict(future_dates)

# %%
prediction.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1949-01-01  106.354536   56.041567  114.798131   106.354536   106.354536
# 1 1949-02-01  108.537164   49.865485  105.500473   108.537164   108.537164
# 2 1949-03-01  110.508569   80.947031  137.839774   110.508569   110.508569
# 3 1949-04-01  112.691197   81.300806  136.047844   112.691197   112.691197
# 4 1949-05-01  114.803417   83.570951  139.273229   114.803417   114.803417
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0      -21.952141            -21.952141            -21.952141 -21.952141
# 1      -30.711556            -30.711556            -30.711556 -30.711556
# 2       -0.481427             -0.481427             -0.481427  -0.481427
# 3       -5.189524             -5.189524             -5.189524  -5.189524
# 4       -3.790598             -3.790598             -3.790598  -3.790598
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -21.952141    -21.952141                   0.0
# 1    -30.711556    -30.711556                   0.0
# 2     -0.481427     -0.481427                   0.0
# 3     -5.189524     -5.189524                   0.0
# 4     -3.790598     -3.790598                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                         0.0                         0.0   84.402395
# 1                         0.0                         0.0   77.825607
# 2                         0.0                         0.0  110.027143
# 3                         0.0                         0.0  107.501673
# 4                         0.0                         0.0  111.012819

# %% [markdown]
# ## Plot the predicted projection

# %%
model.plot(prediction)

# %% [markdown]
# ## Visualize Each Component [Trends,yearly]

# %%
model.plot_components(prediction)

# %% [markdown]
# ## Time Series Analysis

# %%
df.head()
# Out:
#           ds      y
# 0 1949-01-01  112.0
# 1 1949-02-01  118.0
# 2 1949-03-01  132.0
# 3 1949-04-01  129.0
# 4 1949-05-01  121.0

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# 13:06:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:11 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:14 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:17 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:20 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:23 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:25 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:28 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:30 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:31 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:33 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:34 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:36 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:43 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:46 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:48 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:50 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:59 - cmdstanpy - INFO - Chain [1] done processing
#           ds        yhat  yhat_lower  yhat_upper      y     cutoff
# 0 1951-02-01  157.055015  156.771769  157.375580  150.0 1951-01-18
# 1 1951-03-01  169.883776  168.912997  170.902635  178.0 1951-01-18
# 2 1951-04-01  158.096157  156.034844  160.210608  163.0 1951-01-18
# 3 1951-05-01  143.156958  139.808105  146.678493  172.0 1951-01-18
# 4 1951-06-01  176.874030  172.111770  181.854304  178.0 1951-01-18

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape     smape  \
# 0 40 days  1087.719620  32.980595  25.892372  0.078565  0.074301  0.079599
# 1 42 days  1014.353481  31.848916  25.304386  0.077230  0.074301  0.077928
# 2 46 days   911.658083  30.193676  24.807433  0.079562  0.084627  0.079281
# 3 47 days  1046.027378  32.342347  26.978844  0.082761  0.086179  0.082861
# 4 48 days  1034.798608  32.168286  26.389479  0.080657  0.086179  0.080833
#
#    coverage
# 0  0.227273
# 1  0.181818
# 2  0.136364
# 3  0.136364
# 4  0.181818

# %%
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape  coverage
# 0 40 days  1089.123674  33.001874  25.952024  0.078971  0.073690  0.227273
# 1 42 days  1014.683902  31.854103  25.290641  0.077224  0.073690  0.181818
# 2 46 days   911.993612  30.199232  24.793810  0.079557  0.084023  0.136364
# 3 47 days  1046.625579  32.351593  26.911913  0.082348  0.085498  0.136364
# 4 48 days  1035.396122  32.177572  26.322507  0.080244  0.085498  0.181818

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')
# Out:
# c:\Python310\lib\site-packages\prophet\plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# c:\Python310\lib\site-packages\prophet\plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
